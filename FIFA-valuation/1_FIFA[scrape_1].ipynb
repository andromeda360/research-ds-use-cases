# %% [markdown]
# # Importing libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import urllib
#pd.pandas.set_option('display.max_columns',None)
re=requests.get('https://sofifa.com/?showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy')
#Creating soup
soup=BeautifulSoup(re.text,'html.parser')

# %%
table=soup.find('table',{'class':'table table-hover persist-area'})
for i in soup.find('td',class_='col col-pi'):
    print(i.text.strip())
# Out:
# 203263

# %% [markdown]
# Creating empty dataframe of only contains attributes Names

# %%
headers=[]
table=soup.find('table',{'class':'table table-hover persist-area'})

for h in table.find_all('th'):
    title=h.text.strip()
    headers.append(title)
df=pd.DataFrame(columns=headers)

# %%
df
# Out:
# Empty DataFrame
# Columns: [, Name, Age, OVA, POT, Team & Contract, ID, Height, Weight, foot, BOV, BP, Growth, Joined, Loan Date End, Value, Wage, Release Clause, Attacking, Crossing, Finishing, Heading Accuracy, Short Passing, Volleys, Skill, Dribbling, Curve, FK Accuracy, Long Passing, Ball Control, Movement, Acceleration, Sprint Speed, Agility, Reactions, Balance, Power, Shot Power, Jumping, Stamina, Strength, Long Shots, Mentality, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Defending, Marking, Standing Tackle, Sliding Tackle, Goalkeeping, GK Diving, GK Handling, GK Kicking, GK Positioning, GK Reflexes, Total, Base Stats, W/F, SM, A/W, D/W, IR, Body Type, PAC, SHO, PAS, DRI, DEF, PHY]
# Index: []
#
# [0 rows x 73 columns]

# %%
#Page ranges from 0 to 19980 with step size 60
pages=np.arange(1,19980,60)

# %% [markdown]
# Collecting all Information from website by Iterating each page of table row, and each value in a row and storing it in exsisting DataFrame

# %%
#Collecting all Information from website by Iterating each page of table row, and each value in a row and storing it in a DataFrame
for i in pages:
    i=requests.get('https://sofifa.com/?showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&offset='+str(i)+'')
    soup=BeautifulSoup(i.text,'html.parser')
    table=soup.find('table',{'class':'table table-hover persist-area'})
    for j in table.find_all('tr')[1:]:
        values=j.find_all('td')
        value=[k.text.strip() for k in values]
        length=len(df)
        df.loc[length]=value

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df
# Out:
#                                                           \
# 0      FIFA 23 Sep 1, 202267  66 Crossing79  83 Short...
# 1      FIFA 23 Sep 1, 202267  70 Crossing66  68 Headi...
# 2
# 3      FIFA 23 Sep 1, 202260  66 Finishing77  80 Drib...
# 4      FIFA 23 Sep 1, 202275  73 Acceleration70  68 S...
# ...                                                  ...
# 19975
# 19976
# 19977
# 19978  FIFA 23 Sep 1, 202269  70 Agility66  67 Stamin...
# 19979
#
#                           Name Age OVA POT  \
# 0         J. Musiala CM LM CAM  19  81  90
# 1                   K. Koné CM  21  77  86
# 2      K. Kvaratskhelia LW CAM  21  74  84
# 3             M. Mudryk LM CAM  21  74  84
# 4           R. Cherki LW ST RW  18  73  88
# ...                        ...  ..  ..  ..
# ...            ...      ...          ...          ...     ...       ...
# 19975           64      353           73           78      69        55
# 19976           70      392           81           82      80        59
# 19977           62      341           75           80      71        60
# 19978           76      350           74           71      70        68
# 19979           67      360           73           70      75        58
#
#       Balance Power Shot Power Jumping Stamina Strength Long Shots Mentality  \
# 0          92   329         71      55      77       53         73       329
# 1          76   355         74      70      75       68         68       339
# 2          71   328         70      59      67       68         64       302
# 3          73   303         67      60      64       53         59       284
# 4          83   291         76      31      53       65         66       277
# ...       ...   ...        ...     ...     ...      ...        ...       ...
# 19975      78   277         46      66      89       54         22       232
# 19976      90   320         70      59      80       46         65       265
# 19977      55   298         60      51      70       47         70       279
# 19978      67   325         70      53      67       66         69       296
# 19979      84   245         61      59      43       35         47       232
#
#       Aggression Interceptions Positioning Vision Penalties Composure  \
# 0             59            65          76     78        51        82
# 1             71            67          69     78        54        76
# 2             61            37          69     72        63        73
# 3             62            28          69     73        52        70
# 4             57            22          69     68        61        75
# ...          ...           ...         ...    ...       ...       ...
# 19975         40            67          42     39        44        51
# 19976         38            27          62     63        75        60
# 19977         33            58          60     60        68        63
# 19978         44            52          73     65        62        60
# 19979         43            28          48     58        55        65
#
#       Defending Marking Standing Tackle Sliding Tackle Goalkeeping GK Diving  \
# 0           196      64              63             69          42         6
# 1           208      64              74             70          51        11
# 2           114      41              39             34          54         9
# 3           141      51              52             38          49        10
# 4            57      19              23             15          43         7
# ...         ...     ...             ...            ...         ...       ...
# 19975       196      63              67             66          52         8
# 19976       110      38              32             40          50         7
# 19977       178      55              63             60          58        11
# 19978       146      46              52             48          50         9
# 19979       124      46              36             42          40         5
#
#       GK Handling GK Kicking GK Positioning GK Reflexes Total Base Stats W/F  \
# 0               9          8              8          11  2010        434   4
# 1              10         11              9          10  2027        435   3
# 2              15          8             14           8  1873        405   5
# 3              12         14              6           7  1805        399   4
# 4              14          6              8           8  1705        368   5
# ...           ...        ...            ...         ...   ...        ...  ..
# 19975           9          9             13          13  1613        352   2
# 19976          10         14             14           5  1789        378   3
# 19977           9         14             13          11  1745        373   3
# 19978          14         10             11           6  1846        394   3
# 19979           7          6             15           7  1570        332   3
#
#       SM     A/W     D/W IR         Body Type PAC SHO PAS DRI DEF PHY
# 0      4  Medium  Medium  1    Lean (170-185)  75  73  75  87  63  60
# 1      4    High    High  1       Lean (185+)  71  69  74  81  69  70
# 2      4  Medium  Medium  1  Normal (170-185)  81  66  71  79  41  66
# 3      4    High  Medium  1    Lean (170-185)  88  63  67  78  44  58
# 4      5    High     Low  1  Stocky (170-185)  70  67  68  82  21  59
# ...   ..     ...     ... ..               ...  ..  ..  ..  ..  ..  ..
# 19975  2    High    High  1    Lean (170-185)  76  33  58  60  64  61
# 19976  4    High     Low  1       Lean (170-)  82  69  66  73  34  54
# 19977  3  Medium  Medium  1    Lean (170-185)  78  60  60  66  59  50
# 19978  3  Medium  Medium  1    Lean (170-185)  72  70  67  73  50  61
# 19979  3  Medium  Medium  1     Normal (170-)  71  51  60  71  39  40
#
# [19980 rows x 73 columns]

# %% [markdown]
# Storing it as a csv file

# %%
df.to_csv('newdata_1.csv',index=False)
